# %% [markdown]
# ## Decision Tree - Classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("penguins_size.csv")
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# ## Exploratory Data Analysis and Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
10/344
# Out:
# 0.029069767441860465

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            334 non-null    object
#  1   island             334 non-null    object
#  2   culmen_length_mm   334 non-null    float64
#  3   culmen_depth_mm    334 non-null    float64
#  4   flipper_length_mm  334 non-null    float64
#  5   body_mass_g        334 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.9+ KB

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 4  Adelie  Torgersen              36.7             19.3              193.0
# 5  Adelie  Torgersen              39.3             20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 4       3450.0  FEMALE
# 5       3650.0    MALE

# %%
df["sex"].unique()
# Out:
# array(['MALE', 'FEMALE', '.'], dtype=object)

# %%
df["island"].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df["species"].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df[df["sex"]== "."]
# Out:
#     species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 336  Gentoo  Biscoe              44.5             15.7              217.0
#
#      body_mass_g sex
# 336       4875.0   .

# %%
df[df.species =="Gentoo"].groupby("sex").describe().T
# Out:
# sex                           .       FEMALE         MALE
# culmen_length_mm  count     1.0    58.000000    61.000000
#                   mean     44.5    45.563793    49.473770
#                   std       NaN     2.051247     2.720594
#                   min      44.5    40.900000    44.400000
#                   25%      44.5    43.850000    48.100000
#                   50%      44.5    45.500000    49.500000
#                   75%      44.5    46.875000    50.500000
#                   max      44.5    50.500000    59.600000
# culmen_depth_mm   count     1.0    58.000000    61.000000
#                   mean     15.7    14.237931    15.718033
#                   std       NaN     0.540249     0.741060
#                   min      15.7    13.100000    14.100000
#                   25%      15.7    13.800000    15.200000
#                   50%      15.7    14.250000    15.700000
#                   75%      15.7    14.600000    16.100000
#                   max      15.7    15.500000    17.300000
# flipper_length_mm count     1.0    58.000000    61.000000
#                   mean    217.0   212.706897   221.540984
#                   std       NaN     3.897856     5.673252
#                   min     217.0   203.000000   208.000000
#                   25%     217.0   210.000000   218.000000
#                   50%     217.0   212.000000   221.000000
#                   75%     217.0   215.000000   225.000000
#                   max     217.0   222.000000   231.000000
# body_mass_g       count     1.0    58.000000    61.000000
#                   mean   4875.0  4679.741379  5484.836066
#                   std       NaN   281.578294   313.158596
#                   min    4875.0  3950.000000  4750.000000
#                   25%    4875.0  4462.500000  5300.000000
#                   50%    4875.0  4700.000000  5500.000000
#                   75%    4875.0  4875.000000  5700.000000
#                   max    4875.0  5200.000000  6300.000000

# %%
df.loc[336, "sex"] = "MALE"

# %%
df.loc[336, "sex"]
# Out:
# 'MALE'

# %% [markdown]
# ## Visualization

# %%
df["species"].value_counts()
# Out:
# Adelie       146
# Gentoo       120
# Chinstrap     68
# Name: species, dtype: int64

# %%
sns.countplot(x="species", data = df);

# %%
sns.catplot(x='species', data=df, kind='count',col='sex')

# %%
plt.figure(figsize=(12,6))
sns.pairplot(df,hue='species',palette='Dark2')

# %%
df.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df_2 = df.copy()
df_2["species"] = df_2["species"].map({'Adelie':0, 'Chinstrap':1, 'Gentoo':2})

# %%
from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df_2['culmen_length_mm'], df_2['flipper_length_mm'], df_2['species'], c =df_2['species'] );

# %%
df.select_dtypes("number")
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
# [334 rows x 4 columns]

# %%
# df._get_numeric_data()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df._get_numeric_data().corr(),annot=True, cmap='viridis')
plt.title("Correlation Matrix")

plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
df.drop("species", axis =1)
# Out:
#         island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Torgersen              39.1             18.7              181.0
# 1    Torgersen              39.5             17.4              186.0
# 2    Torgersen              40.3             18.0              195.0
# 4    Torgersen              36.7             19.3              193.0
# 5    Torgersen              39.3             20.6              190.0
# ..         ...               ...              ...                ...
# 338     Biscoe              47.2             13.7              214.0
# 340     Biscoe              46.8             14.3              215.0
# 341     Biscoe              50.4             15.7              222.0
# 342     Biscoe              45.2             14.8              212.0
# 343     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 4         3450.0  FEMALE
# 5         3650.0    MALE
# ..           ...     ...
# 338       4925.0  FEMALE
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [334 rows x 6 columns]

# %%
pd.get_dummies(df.drop("species", axis =1), drop_first =True)
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0                39.1             18.7              181.0       3750.0
# 1                39.5             17.4              186.0       3800.0
# 2                40.3             18.0              195.0       3250.0
# 4                36.7             19.3              193.0       3450.0
# 5                39.3             20.6              190.0       3650.0
# ..                ...              ...                ...          ...
# 338              47.2             13.7              214.0       4925.0
# 340              46.8             14.3              215.0       4850.0
# 341              50.4             15.7              222.0       5750.0
# 342              45.2             14.8              212.0       5200.0
# 343              49.9             16.1              213.0       5400.0
#
#      island_Dream  island_Torgersen  sex_MALE
# 0               0                 1         1
# 1               0                 1         0
# 2               0                 1         0
# 4               0                 1         0
# 5               0                 1         1
# ..            ...               ...       ...
# 338             0                 0         0
# 340             0                 0         0
# 341             0                 0         1
# 342             0                 0         0
# 343             0                 0         1
#
# [334 rows x 7 columns]

# %% [markdown]
# ## Train | Test Split

# %%
X = pd.get_dummies(df.drop('species',axis=1),drop_first=True)
y = df['species']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# # Modelling - Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT_model = DecisionTreeClassifier(random_state=101)

# %%
DT_model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=101)

# %%
y_pred = DT_model.predict(X_test)

# %% [markdown]
# ## Model Performance on Classification Tasks

# %%
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[40,  1,  0],
#        [ 2, 21,  0],
#        [ 0,  0, 37]], dtype=int64)

# %%
plot_confusion_matrix(DT_model,X_test,y_test)

# %%
from yellowbrick.classifier import ClassPredictionError

visualizer = ClassPredictionError(DT_model)

# Fit the training data to the visualizer
visualizer.fit(X_train, y_train)

# Evaluate the model on the test data
visualizer.score(X_test, y_test)

# Draw visualization
visualizer.poof();

# %%
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[40  1  0]
#  [ 2 21  0]
#  [ 0  0 37]]
#               precision    recall  f1-score   support
#
#       Adelie       0.95      0.98      0.96        41
#    Chinstrap       0.95      0.91      0.93        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.97      0.96      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %% [markdown]
# ## Cross Validate

# %%
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import make_scorer

# %%
model = DecisionTreeClassifier(max_depth=None, random_state=101)

scores = cross_validate(model, X_train, y_train, scoring = ["accuracy", "precision_macro", "recall_macro", "f1_macro"], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores
# Out:
#     fit_time  score_time  test_accuracy  test_precision_macro  \
# 1   0.002999    0.003001       0.958333              0.969697
# 2   0.002001    0.003001       0.958333              0.966667
# 3   0.002001    0.003000       0.916667              0.911111
# 4   0.003020    0.000000       0.956522              0.962963
# 5   0.000000    0.000000       1.000000              1.000000
# 6   0.000000    0.000000       1.000000              1.000000
# 7   0.015625    0.000000       1.000000              1.000000
# 8   0.000000    0.000000       1.000000              1.000000
# 9   0.000000    0.000000       0.869565              0.900000
# 10  0.015626    0.000000       1.000000              1.000000
#
#     test_recall_macro  test_f1_macro
# 1            0.933333       0.947090
# 2            0.966667       0.964912
# 3            0.929630       0.916756
# 4            0.933333       0.943355
# 5            1.000000       1.000000
# 6            1.000000       1.000000
# 7            1.000000       1.000000
# 8            1.000000       1.000000
# 9            0.856061       0.867725
# 10           1.000000       1.000000

# %%
df_scores.mean()[2:]
# Out:
# test_accuracy           0.965942
# test_precision_macro    0.971044
# test_recall_macro       0.961902
# test_f1_macro           0.963984
# dtype: float64

# %% [markdown]
# ## Feature Importances

# %%
DT_model.feature_importances_
# Out:
# array([0.32591819, 0.05289252, 0.54282921, 0.        , 0.07836008,
#        0.        , 0.        ])

# %%
df_f_i = pd.DataFrame(index=X.columns, data = DT_model.feature_importances_, 
                      columns = ["Feature Importance"]).sort_values("Feature Importance")
df_f_i
# Out:
#                    Feature Importance
# body_mass_g                  0.000000
# island_Torgersen             0.000000
# sex_MALE                     0.000000
# culmen_depth_mm              0.052893
# island_Dream                 0.078360
# culmen_length_mm             0.325918
# flipper_length_mm            0.542829

# %%
sns.barplot(x = df_f_i.index, y = 'Feature Importance', data = df_f_i)
plt.xticks(rotation = 90)
plt.tight_layout()

# %%
X2 = X.drop(columns = ["flipper_length_mm"]) 
# The feature that weighs too much on the estimate can sometimes cause overfitting. For this reason, the most important feature can be dropped and the scores can be checked again

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y, test_size=0.3, random_state=101)

# %%
DT2_model = DecisionTreeClassifier(random_state=101)

# %%
DT2_model.fit(X_train2, y_train2)
# Out:
# DecisionTreeClassifier(random_state=101)

# %%
y_pred2 = DT2_model.predict(X_test2)

# %%
print(confusion_matrix(y_test2, y_pred2))
print(classification_report(y_test2, y_pred2))
# Out:
# [[41  0  0]
#  [ 1 22  0]
#  [ 1  0 36]]
#               precision    recall  f1-score   support
#
#       Adelie       0.95      1.00      0.98        41
#    Chinstrap       1.00      0.96      0.98        23
#       Gentoo       1.00      0.97      0.99        37
#
#     accuracy                           0.98       101
#    macro avg       0.98      0.98      0.98       101
# weighted avg       0.98      0.98      0.98       101

# %%
model = DecisionTreeClassifier(random_state=101)

scores = cross_validate(model, X_train2, y_train2, scoring = ["accuracy", "precision_macro", "recall_macro", "f1_macro"], cv = 10)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores
# Out:
#     fit_time  score_time  test_accuracy  test_precision_macro  \
# 1   0.003001    0.057281       1.000000              1.000000
# 2   0.000000    0.015626       1.000000              1.000000
# 3   0.000000    0.000000       0.958333              0.944444
# 4   0.000000    0.000000       1.000000              1.000000
# 5   0.000000    0.015627       1.000000              1.000000
# 6   0.000000    0.000000       1.000000              1.000000
# 7   0.000000    0.000000       1.000000              1.000000
# 8   0.015625    0.000000       1.000000              1.000000
# 9   0.000000    0.000000       1.000000              1.000000
# 10  0.000000    0.000000       0.956522              0.962963
#
#     test_recall_macro  test_f1_macro
# 1            1.000000       1.000000
# 2            1.000000       1.000000
# 3            0.966667       0.952153
# 4            1.000000       1.000000
# 5            1.000000       1.000000
# 6            1.000000       1.000000
# 7            1.000000       1.000000
# 8            1.000000       1.000000
# 9            1.000000       1.000000
# 10           0.969697       0.964519

# %%
df_scores.mean()[2:]
# Out:
# test_accuracy           0.991486
# test_precision_macro    0.990741
# test_recall_macro       0.993636
# test_f1_macro           0.991667
# dtype: float64

# %% [markdown]
# ## Visualize the Tree

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(12,8))
plot_tree(DT_model);

# %%
plt.figure(figsize=(12,8),dpi=150)
plot_tree(DT_model, filled=True, feature_names=X.columns, class_names=df.species.unique());

# %% [markdown]
# ## Understanding Hyperparameters
#
# ### Max Depth

# %%
def report_model(model):
    model_pred = model.predict(X_test)
    print('\n')
    print(confusion_matrix(y_test, model_pred))
    print('\n')
    print(classification_report(y_test,model_pred))
    print('\n')
    plt.figure(figsize=(12,8),dpi=150)
    plot_tree(model,filled=True, feature_names=X.columns, class_names=df.species.unique());

# %%
pruned_tree = DecisionTreeClassifier(max_depth=3, random_state=101)
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=101)

# %%
report_model(pruned_tree)
# Out:
# [[39  2  0]
#  [ 1 22  0]
#  [ 0  0 37]]
#
#
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.95      0.96        41
#    Chinstrap       0.92      0.96      0.94        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.96      0.97      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %% [markdown]
# ## Max Leaf Nodes

# %%
pruned_tree_2 = DecisionTreeClassifier(max_leaf_nodes=5, random_state=101)
pruned_tree_2.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=5, random_state=101)

# %%
report_model(pruned_tree_2)
# Out:
# [[39  2  0]
#  [ 1 22  0]
#  [ 0  0 37]]
#
#
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.95      0.96        41
#    Chinstrap       0.92      0.96      0.94        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.96      0.97      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %% [markdown]
# ## Criterion

# %%
entropy_tree = DecisionTreeClassifier(criterion='entropy', random_state=101,)
entropy_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=101)

# %%
report_model(entropy_tree)
# Out:
# [[40  1  0]
#  [ 2 21  0]
#  [ 0  0 37]]
#
#
#               precision    recall  f1-score   support
#
#       Adelie       0.95      0.98      0.96        41
#    Chinstrap       0.95      0.91      0.93        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.97      0.96      0.97       101
# weighted avg       0.97      0.97      0.97       101

# %% [markdown]
# ## Max_features, Splitter

# %%
tree = DecisionTreeClassifier(splitter = "random", max_features=3)
tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_features=3, splitter='random')

# %%
report_model(tree)
# Out:
# [[41  0  0]
#  [ 2 21  0]
#  [ 0  0 37]]
#
#
#               precision    recall  f1-score   support
#
#       Adelie       0.95      1.00      0.98        41
#    Chinstrap       1.00      0.91      0.95        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.98       101
#    macro avg       0.98      0.97      0.98       101
# weighted avg       0.98      0.98      0.98       101

# %% [markdown]
# ## Find Best Parameters

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {"criterion": ["entropy", "gini"], 
       "splitter" : ["best", "random"],
       "max_depth": [1,2,3,4,5,6,7],
       "min_samples_leaf": [0.1,1,2,3,4,5,6,7,10]}

# %%
model = DecisionTreeClassifier()
decision_grid_model = GridSearchCV(model, param_grid, verbose=3, refit=True)

# %%
decision_grid_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 252 candidates, totalling 1260 fits
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=best, score=0.766, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=best, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=best, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=best, score=0.804, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=best, score=0.783, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=random, score=0.745, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=random, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=random, score=0.723, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=random, score=0.674, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=0.1, splitter=random, score=0.543, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=best, score=0.766, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=best, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=best, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=best, score=0.804, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=best, score=0.783, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=random, score=0.766, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=random, score=0.553, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=random, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=random, score=0.761, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=1, splitter=random, score=0.674, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=best, score=0.766, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=best, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=best, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=best, score=0.804, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=best, score=0.783, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=random, score=0.553, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=random, score=0.553, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=random, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=random, score=0.543, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=2, splitter=random, score=0.739, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=best, score=0.766, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=best, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=best, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=best, score=0.804, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=best, score=0.783, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=random, score=0.553, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=random, score=0.553, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=random, score=0.745, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=random, score=0.543, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=3, splitter=random, score=0.543, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=best, score=0.766, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=best, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=best, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=best, score=0.804, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=best, score=0.783, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=random, score=0.553, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=random, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=random, score=0.553, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=random, score=0.804, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=4, splitter=random, score=0.543, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=best, score=0.766, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=best, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=best, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=best, score=0.804, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=best, score=0.783, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=random, score=0.702, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=random, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=random, score=0.745, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=random, score=0.543, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=5, splitter=random, score=0.543, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=best, score=0.766, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=best, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=best, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=best, score=0.804, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=best, score=0.783, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=random, score=0.745, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=random, score=0.553, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=random, score=0.553, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=random, score=0.761, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=6, splitter=random, score=0.630, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=best, score=0.766, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=best, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=best, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=best, score=0.804, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=best, score=0.783, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=random, score=0.553, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=random, score=0.766, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=random, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=random, score=0.761, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=7, splitter=random, score=0.761, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=best, score=0.766, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=best, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=best, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=best, score=0.804, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=best, score=0.783, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=random, score=0.745, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=random, score=0.553, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=random, score=0.553, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=random, score=0.804, total=   0.0s
# [CV] criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=1, min_samples_leaf=10, splitter=random, score=0.739, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=random, score=0.872, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=random, score=0.872, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=random, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=random, score=0.804, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=0.1, splitter=random, score=0.826, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=random, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=random, score=0.872, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=random, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=1, splitter=random, score=0.826, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=random, score=0.872, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=random, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=2, splitter=random, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=random, score=0.723, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=random, score=0.915, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=random, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=random, score=0.826, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=3, splitter=random, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=random, score=0.745, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=random, score=0.617, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=random, score=0.761, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=4, splitter=random, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=best, score=0.915, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=random, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=random, score=0.766, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=random, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=random, score=0.848, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=5, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=random, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=random, score=0.638, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=random, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=random, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=6, splitter=random, score=0.783, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=random, score=0.809, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=random, score=0.894, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=random, score=0.851, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=random, score=0.870, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=7, splitter=random, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=random, score=0.872, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=random, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=random, score=0.745, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=2, min_samples_leaf=10, splitter=random, score=0.783, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=random, score=0.872, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=random, score=0.745, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=random, score=0.979, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=random, score=0.739, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=0.1, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=best, score=0.979, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=best, score=1.000, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=random, score=0.915, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=random, score=0.872, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=random, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=random, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=1, splitter=random, score=0.935, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=best, score=0.979, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=best, score=1.000, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=random, score=0.979, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=random, score=0.979, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=best, score=1.000, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=best, score=1.000, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=random, score=0.979, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=random, score=0.851, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, splitter=random, score=0.848, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=best, score=0.979, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=random, score=0.979, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=random, score=0.894, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=random, score=0.787, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, splitter=random, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=random, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=random, score=0.894, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=random, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=5, splitter=random, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=random, score=0.745, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=random, score=0.872, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=random, score=0.935, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=6, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=best, score=0.935, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=random, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=random, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=random, score=0.870, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=7, splitter=random, score=0.826, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=best
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=random, score=0.851, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=random, score=0.851, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=random, score=0.872, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=random, score=0.826, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=random
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=10, splitter=random, score=0.935, total=   0.0s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=0.1, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=0.1, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=0.1, splitter=best, score=0.936, total=   0.0s
# ...
# [CV] criterion=gini, max_depth=6, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=6, min_samples_leaf=10, splitter=random, score=0.978, total=   0.0s
# [CV] criterion=gini, max_depth=6, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=6, min_samples_leaf=10, splitter=random, score=0.978, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=best, score=0.894, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=best
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=random, score=0.872, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=random, score=0.809, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=random, score=0.915, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=random, score=0.913, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=0.1, splitter=random, score=0.913, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=1, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=1, splitter=best, score=0.979, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=1, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=1, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=1, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=1, splitter=best, score=0.979, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=1, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=1, splitter=best, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=1, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=1, splitter=best, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=1, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=1, splitter=random, score=0.936, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=1, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=1, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=1, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=1, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=2, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=2, splitter=best, score=0.979, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=2, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=2, splitter=best, score=0.915, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=2, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=2, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=2, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=2, splitter=best, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=2, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=2, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=2, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=2, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=2, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=2, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=2, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=2, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=3, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=3, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=3, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=3, splitter=best, score=0.915, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=3, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=3, splitter=best, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=3, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=3, splitter=best, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=3, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=3, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=3, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=3, splitter=random, score=0.936, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=3, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=3, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=3, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=3, splitter=random, score=0.979, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=3, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=3, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=3, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=3, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=4, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=4, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=4, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=4, splitter=best, score=0.915, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=4, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=4, splitter=best, score=0.979, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=4, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=4, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=4, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=4, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=4, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=4, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=4, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=4, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=4, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=4, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=5, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=5, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=5, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=5, splitter=best, score=0.915, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=5, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=5, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=5, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=5, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=5, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=5, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=5, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=5, splitter=random, score=0.766, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=5, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=5, splitter=random, score=0.936, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=5, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=5, splitter=random, score=0.979, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=5, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=5, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=5, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=5, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=6, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=6, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=6, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=6, splitter=best, score=0.894, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=6, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=6, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=6, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=6, splitter=best, score=0.978, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=6, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=6, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=6, splitter=random, score=0.979, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=6, splitter=random, score=0.766, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=6, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=6, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=6, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=6, splitter=random, score=0.848, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=7, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=7, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=7, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=7, splitter=best, score=0.894, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=7, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=7, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=7, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=7, splitter=best, score=0.935, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=7, splitter=best ..
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=7, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=7, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=7, splitter=random, score=0.915, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=7, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=7, splitter=random, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=7, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=7, splitter=random, score=0.894, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=7, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=7, splitter=random, score=0.978, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=7, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=7, splitter=random, score=1.000, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=10, splitter=best .
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=10, splitter=best, score=0.957, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=10, splitter=best .
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=10, splitter=best, score=0.894, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=10, splitter=best .
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=10, splitter=best, score=0.936, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=10, splitter=best .
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=10, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=10, splitter=best .
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=10, splitter=best, score=0.913, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=10, splitter=random, score=0.979, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=10, splitter=random, score=0.894, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=10, splitter=random, score=0.915, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=10, splitter=random, score=0.935, total=   0.0s
# [CV] criterion=gini, max_depth=7, min_samples_leaf=10, splitter=random
# [CV]  criterion=gini, max_depth=7, min_samples_leaf=10, splitter=random, score=0.935, total=   0.0s
# [Parallel(n_jobs=1)]: Done 1260 out of 1260 | elapsed:    4.6s finished
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [1, 2, 3, 4, 5, 6, 7],
#                          'min_samples_leaf': [0.1, 1, 2, 3, 4, 5, 6, 7, 10],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
decision_grid_model.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 7,
#  'min_samples_leaf': 1,
#  'splitter': 'random'}

# %%
y_pred_grid = decision_grid_model.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred_grid))
print(classification_report(y_test, y_pred_grid))
# Out:
# [[39  2  0]
#  [ 1 22  0]
#  [ 0  0 37]]
#               precision    recall  f1-score   support
#
#       Adelie       0.97      0.95      0.96        41
#    Chinstrap       0.92      0.96      0.94        23
#       Gentoo       1.00      1.00      1.00        37
#
#     accuracy                           0.97       101
#    macro avg       0.96      0.97      0.97       101
# weighted avg       0.97      0.97      0.97       101
